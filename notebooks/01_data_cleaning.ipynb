# %%
# Import libraries
import pandas as pd
import numpy as np

# Load the raw data file
file_path = '../data/raw_data.csv'
df = pd.read_csv(file_path)

# Display basic information about the dataset
print("\n🔎 Initial Dataset Info:")
print(df.info())

# Display the first 5 rows to understand the data structure
print("\n📊 Initial Dataset Sample:")
print(df.head())

# Display basic statistical details of numerical columns
print("\n📈 Summary Statistics:")
print(df.describe())

# ✅ Step 1: Handle Missing Values
# Fill missing Agent_Rating with mean value and Weather with mode (most frequent value)
df.fillna({'Agent_Rating': df['Agent_Rating'].mean(), 
           'Weather': df['Weather'].mode()[0]}, inplace=True)

# ✅ Step 2: Handle Missing Time Values
# Fill missing Order_Time and Pickup_Time with default '00:00:00'
df.fillna({'Order_Time': '00:00:00', 
           'Pickup_Time': '00:00:00'}, inplace=True)

# ✅ Step 3: Confirm Fixes
print("\n✅ Updated Dataset Info (After Handling Missing Values):")
print(df.info())

# ✅ Step 4: Display Sample Output After Cleaning
print("\n📊 Sample After Cleaning:")
print(df.head())
# Out:
# 🔎 Initial Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  object
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...
